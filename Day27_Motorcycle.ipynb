# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

current_font_list= matplotlib.rcParams['font.family']

font_path ="C:\Windows\Fonts\HMFMMUEX.TTC"
kfont = matplotlib.font_manager.FontProperties(fname= font_path).get_name()


matplotlib.rcParams['font.family'] = [kfont] + current_font_list

pd_data = pd.read_csv('이륜차신고현황_시도별_20230309170345.csv', encoding = 'cp949', header=0)
print(pd_data.head())
print(pd_data.shape)
# Out:
#   시도명(1) 시군구(1)       시점 레벨01(1)    소계   경형    소형    중형   대형
# 0     부산    금정구  2018.01       계  8115  380  2402  5017  316
# 1     부산    금정구  2018.02       계  8117  377  2395  5029  316
# 2     부산    금정구  2018.03       계  8102  371  2384  5034  313
# 3     부산    금정구  2018.04       계  8112  366  2375  5050  321
# 4     부산    금정구  2018.05       계  8130  357  2371  5073  329
# (915, 9)

# %%
b1 = pd_data.groupby(['시군구(1)'])
df_group = b1.mean()
df_group_pv = df_group.reset_index().pivot('시군구(1)', '시점', '경형')
sns.heatmap(df_group_pv)
# Out:
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_7644\133161148.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_group = b1.mean()
# C:\Users\ITPS\AppData\Local\Temp\ipykernel_7644\133161148.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   df_group_pv = df_group.reset_index().pivot('시군구(1)', '시점', '경형')
# <AxesSubplot: xlabel='시점', ylabel='시군구(1)'>

# %%
#시점을 년, 월로 나누기

#x = pd_data['시점'].unique()
#print(x)
pd_data['시점'].apply(lambda x:str(x//1)) #년도만
pd_data['시점'].apply(lambda x:str(x).split('.')[1]) #월
#pd_data['시점'].apply(lambda x:str(x).split('.')[0]) #년도

#print(pd_data['시점'])
#pd_data['시점'] = pd_data['시점'].apply(lambda x: x.split()[0])
# Out:
# 0      01
# 1      02
# 2      03
# 3      04
# 4      05
#        ..
# 910    09
# 911     1
# 912    11
# 913    12
# 914    01
# Name: 시점, Length: 915, dtype: object
